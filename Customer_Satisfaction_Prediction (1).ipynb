# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Displaying Data**

# %%
df=pd.read_csv("/content/customer_support_tickets.csv")
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# ...

# %% [markdown]
# **Understanding Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8469 entries, 0 to 8468
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Ticket ID                     8469 non-null   int64
#  1   Customer Name                 8469 non-null   object
#  2   Customer Email                8469 non-null   object
#  3   Customer Age                  8469 non-null   int64
#  4   Customer Gender               8469 non-null   object
#  5   Product Purchased             8469 non-null   object
#  6   Date of Purchase              8469 non-null   object
#  7   Ticket Type                   8469 non-null   object
#  8   Ticket Subject                8469 non-null   object
#  9   Ticket Description            8469 non-null   object
#  10  Ticket Status                 8469 non-null   object
#  11  Resolution                    2769 non-null   object
# ...

# %%
df.describe()
# Out:
#          Ticket ID  Customer Age  Customer Satisfaction Rating
# count  8469.000000   8469.000000                   2769.000000
# mean   4235.000000     44.026804                      2.991333
# std    2444.934048     15.296112                      1.407016
# min       1.000000     18.000000                      1.000000
# 25%    2118.000000     31.000000                      2.000000
# 50%    4235.000000     44.000000                      3.000000
# 75%    6352.000000     57.000000                      4.000000
# max    8469.000000     70.000000                      5.000000

# %%
df.shape
# Out:
# (8469, 17)

# %%
df.value_counts()
# Out:
# Ticket ID  Customer Name      Customer Email            Customer Age  Customer Gender  Product Purchased          Date of Purchase  Ticket Type           Ticket Subject        Ticket Description                                                                                                                                                                                                                                                                                                                                Ticket Status  Resolution                                            Ticket Priority  Ticket Channel  First Response Time  Time to Resolution   Customer Satisfaction Rating
# ...

# %%
df['Customer Satisfaction Rating'].value_counts()
# Out:
# Customer Satisfaction Rating
# 3.0    580
# 1.0    553
# 2.0    549
# 5.0    544
# 4.0    543
# Name: count, dtype: int64

# %% [markdown]
# **Checking for Duplicate Values**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8464    False
# 8465    False
# 8466    False
# 8467    False
# 8468    False
# Length: 8469, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Checking For null Values**

# %%
df.isna().sum()
# Out:
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Resolution                      5700
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating    5700
# dtype: int64

# %% [markdown]
# **Drop Rows where target is missing**

# %%
df = df.dropna(subset=['Customer Satisfaction Rating'])

# %% [markdown]
# **Drop Irrelevent Columns**

# %%
drop_cols = [
    'Ticket ID',
    'Customer Name',
    'Customer Email',
    'Ticket Description',
    'Resolution'
]

df = df.drop(columns=drop_cols)

# %% [markdown]
# **Convert Date Column**

# %%
df['Date of Purchase'] = pd.to_datetime(df['Date of Purchase'])
df['Purchase_Year'] = df['Date of Purchase'].dt.year
df['Purchase_Month'] = df['Date of Purchase'].dt.month

df.drop(columns=['Date of Purchase'], inplace=True)

# %%
df.head()
# Out:
#     Customer Age Customer Gender          Product Purchased  \
# 2             48           Other                   Dell XPS
# 3             27          Female           Microsoft Office
# 4             67          Female           Autodesk AutoCAD
# 10            48            Male            Nintendo Switch
# 11            51            Male  Microsoft Xbox Controller
#
#              Ticket Type   Ticket Subject Ticket Status Ticket Priority  \
# 2        Technical issue  Network problem        Closed             Low
# 3        Billing inquiry   Account access        Closed             Low
# 4        Billing inquiry        Data loss        Closed             Low
# 10  Cancellation request        Data loss        Closed            High
# 11       Product inquiry     Software bug        Closed            High
#
#    Ticket Channel  First Response Time   Time to Resolution  \
# 2    Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# ...

# %% [markdown]
# **Handle Time Columns**

# %%
df.drop(
    columns=['First Response Time', 'Time to Resolution'],
    inplace=True
)

# %%
df.head()
# Out:
#     Customer Age Customer Gender          Product Purchased  \
# 2             48           Other                   Dell XPS
# 3             27          Female           Microsoft Office
# 4             67          Female           Autodesk AutoCAD
# 10            48            Male            Nintendo Switch
# 11            51            Male  Microsoft Xbox Controller
#
#              Ticket Type   Ticket Subject Ticket Status Ticket Priority  \
# 2        Technical issue  Network problem        Closed             Low
# 3        Billing inquiry   Account access        Closed             Low
# 4        Billing inquiry        Data loss        Closed             Low
# 10  Cancellation request        Data loss        Closed            High
# 11       Product inquiry     Software bug        Closed            High
#
#    Ticket Channel  Customer Satisfaction Rating  Purchase_Year  Purchase_Month
# 2    Social media                           3.0           2020               7
# ...

# %%
df.isna().sum()
# Out:
# Customer Age                    0
# Customer Gender                 0
# Product Purchased               0
# Ticket Type                     0
# Ticket Subject                  0
# Ticket Status                   0
# Ticket Priority                 0
# Ticket Channel                  0
# Customer Satisfaction Rating    0
# Purchase_Year                   0
# Purchase_Month                  0
# dtype: int64

# %% [markdown]
# **EDA**

# %%
sns.barplot(x='Customer Gender',y='Customer Satisfaction Rating',data=df,color='green',hue='Ticket Priority')
# Out:
# /tmp/ipython-input-3990164287.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:green'` for the same effect.
#
#   sns.barplot(x='Customer Gender',y='Customer Satisfaction Rating',data=df,color='green',hue='Ticket Priority')
# <Axes: xlabel='Customer Gender', ylabel='Customer Satisfaction Rating'>

# %%
sns.barplot(
    y='Customer Gender',
    x='Purchase_Year',
    hue='Ticket Priority',
    data=df
)
# Out:
# <Axes: xlabel='Purchase_Year', ylabel='Customer Gender'>

# %%
sns.barplot(
    y='Customer Gender',
    x='Purchase_Year',
    color='pink',
    data=df
)
# Out:
# <Axes: xlabel='Purchase_Year', ylabel='Customer Gender'>

# %%
sns.boxplot(y='Customer Satisfaction Rating',color='blue',data=df)
# Out:
# <Axes: ylabel='Customer Satisfaction Rating'>

# %%
plt.pie(df['Ticket Priority'].value_counts(),labels=df['Ticket Priority'].value_counts().index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7dc5414829c0>,
# ...
#  [Text(0.7474708437577542, 0.8070237528921136, 'Critical'),
#   Text(-0.8453168276329279, 0.703874605963735, 'High'),
#   Text(-0.6898736430840906, -0.8567813936926297, 'Medium'),
#   Text(0.8192108235960057, -0.734093745037481, 'Low')])

# %%
sns.countplot(x='Ticket Channel',color='orange',data=df)
# Out:
# <Axes: xlabel='Ticket Channel', ylabel='count'>

# %%
plt.hexbin(
    df['Purchase_Month'],
    df['Customer Satisfaction Rating'],
    gridsize=30
)
plt.xlabel("Purchase_Month")
plt.ylabel("Satisfaction Rating")
plt.title("Purchase_Month vs Satisfaction")
plt.colorbar(label="Count")
plt.show()

# %% [markdown]
# **Feature and Target**

# %%
X = df.drop('Customer Satisfaction Rating', axis=1)
y = df['Customer Satisfaction Rating']

# %% [markdown]
# **Categorical Encoding**

# %%
cat_cols = X.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Customer Gender', 'Product Purchased', 'Ticket Type', 'Ticket Subject',
#        'Ticket Status', 'Ticket Priority', 'Ticket Channel'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in cat_cols:
    X[col] = le.fit_transform(X[col])

# %% [markdown]
# Train Test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.30,random_state=42)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %% [markdown]
# **Make Prediction**

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# **Evaluate Model Performance**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("MAE:", mean_absolute_error(y_test, y_pred))
print("MSE:", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# MAE: 1.224554753309266
# MSE: 2.0422461793020457
# RMSE: 1.4290717894150895
# R² Score: -0.051705915034751415

# %% [markdown]
# **Heatmap**

# %%
num_df = df.select_dtypes(include=['int64', 'int32', 'float64'])
num_df.head()
# Out:
#     Customer Age  Customer Satisfaction Rating  Purchase_Year  Purchase_Month
# 2             48                           3.0           2020               7
# 3             27                           3.0           2020              11
# 4             67                           1.0           2020               2
# 10            48                           1.0           2021               1
# 11            51                           1.0           2021              10

# %%
df_corr=num_df.corr()
df_corr
# Out:
#                               Customer Age  Customer Satisfaction Rating  \
# Customer Age                      1.000000                     -0.003700
# Customer Satisfaction Rating     -0.003700                      1.000000
# Purchase_Year                    -0.001466                     -0.036026
# Purchase_Month                   -0.029688                     -0.014619
#
#                               Purchase_Year  Purchase_Month
# Customer Age                      -0.001466       -0.029688
# Customer Satisfaction Rating      -0.036026       -0.014619
# Purchase_Year                      1.000000        0.002918
# Purchase_Month                     0.002918        1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(
    df_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)
plt.title("Correlation Heatmap")
plt.show()
